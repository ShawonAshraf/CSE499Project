# %%
import os
import pickle

pickle_dir = "vgg16_scratch_pickle"

# %%
def dump_pickle(data, path):
    file_handle = open(path, "wb")
    pickle.dump(data, file_handle)
    file_handle.close()

# %%
kerasModelpath = "kerasBin.h5"

# %%
from keras.models import load_model
import tensorflow as tf
import h5py

model = load_model(kerasModelpath)
# Out:
# Using TensorFlow backend.

# %%
image_dir = "img_test"
images_from_dir = os.listdir(image_dir)

# %%
image_path_list = []
for i in images_from_dir:
    image_path_list.append(os.path.join(image_dir, i))

# %%
from PIL import Image
import numpy as np

def prepare_image(img_path):
    image = Image.open(img_path)
    image = image.resize((150, 150))
    image_array = np.array(image)
    sample = np.array([image_array])

    return sample

# %%
labels = ["fresh", "rotten"]
label_dict = {"fresh": 0, "rotten": 1}

# %%
# generate ground truth dict

def get_ground_truth(path):
    images = os.listdir(path)
    print("Total {} images in {}".format(len(images), path))
    
    ground_truth_dict = {}
    
    for img in images:
        for label in labels:
            if label in img:
                img_path = os.path.join(path, img)
                ground_truth_dict[img_path] = label_dict[label]
                
    return ground_truth_dict

# %%
ground_truth = get_ground_truth(image_dir)
# Out:
# Total 526 images in img_test

# %%
# write out ground truth as pickle

pickle_out_path = os.path.join(pickle_dir, "vgg16_s_ground.pickle")
dump_pickle(data=ground_truth, path=pickle_out_path)

# %%
# now for prediction

result_dict = {}
for image in image_path_list:
    imArray = prepare_image(image)
    try:
        prediction = model.predict(x=imArray)
        index = int(prediction[0][0])
    
        result_dict[image] = label_dict[labels[index]]
    except ValueError as v:
        pass

# %%
pickle_out_path = os.path.join(pickle_dir, "vgg16_s_err.pickle")
dump_pickle(result_dict, pickle_out_path)

# %%
result_dict
# Out:
# {'img_test/fresh_apple_a.jpg': 0,
#  'img_test/fresh_apple_b.jpg': 1,
#  'img_test/fresh_apple_c.JPG': 0,
#  'img_test/fresh_banana_a.jpg': 0,
#  'img_test/fresh_mango_a.jpg': 0,
#  'img_test/fresh_mango_b.jpg': 0,
#  'img_test/fresh_mango_c.jpg': 0,
#  'img_test/fresh_mango_d.jpg': 0,
#  'img_test/fresh_mango_e.jpg': 0,
#  'img_test/fresh_mango_f.jpg': 0,
#  'img_test/fresh_orange_1.jpeg': 0,
#  'img_test/fresh_orange_10.jpeg': 0,
#  'img_test/fresh_orange_100.jpeg': 0,
#  'img_test/fresh_orange_101.jpeg': 0,
#  'img_test/fresh_orange_102.jpeg': 0,
#  'img_test/fresh_orange_103.jpeg': 0,
#  'img_test/fresh_orange_104.jpeg': 0,
#  'img_test/fresh_orange_105.jpeg': 0,
#  'img_test/fresh_orange_106.jpeg': 0,
#  'img_test/fresh_orange_107.jpeg': 0,
#  'img_test/fresh_orange_108.jpeg': 0,
#  'img_test/fresh_orange_109.jpeg': 0,
#  'img_test/fresh_orange_11.jpeg': 0,
#  'img_test/fresh_orange_110.jpeg': 0,
#  'img_test/fresh_orange_111.jpeg': 0,
#  'img_test/fresh_orange_112.jpeg': 0,
#  'img_test/fresh_orange_113.jpeg': 0,
#  'img_test/fresh_orange_114.jpeg': 0,
#  'img_test/fresh_orange_115.jpeg': 0,
#  'img_test/fresh_orange_116.jpeg': 0,
#  'img_test/fresh_orange_117.jpeg': 0,
#  'img_test/fresh_orange_118.jpeg': 0,
#  'img_test/fresh_orange_119.jpeg': 0,
#  'img_test/fresh_orange_12.jpeg': 0,
#  'img_test/fresh_orange_120.jpeg': 0,
#  'img_test/fresh_orange_121.jpeg': 0,
#  'img_test/fresh_orange_122.jpeg': 0,
#  'img_test/fresh_orange_123.jpeg': 0,
#  'img_test/fresh_orange_124.jpeg': 0,
#  'img_test/fresh_orange_125.jpeg': 0,
#  'img_test/fresh_orange_126.jpeg': 0,
#  'img_test/fresh_orange_127.jpeg': 0,
#  'img_test/fresh_orange_128.jpeg': 0,
#  'img_test/fresh_orange_129.jpeg': 0,
#  'img_test/fresh_orange_13.jpeg': 0,
#  'img_test/fresh_orange_130.jpeg': 0,
#  'img_test/fresh_orange_131.jpeg': 1,
#  'img_test/fresh_orange_132.jpeg': 0,
#  'img_test/fresh_orange_133.jpeg': 0,
#  'img_test/fresh_orange_134.jpeg': 0,
#  'img_test/fresh_orange_135.jpeg': 0,
#  'img_test/fresh_orange_136.jpeg': 0,
#  'img_test/fresh_orange_137.jpeg': 0,
#  'img_test/fresh_orange_138.jpeg': 0,
#  'img_test/fresh_orange_139.jpeg': 0,
#  'img_test/fresh_orange_14.jpeg': 0,
#  'img_test/fresh_orange_140.jpeg': 0,
#  'img_test/fresh_orange_141.jpeg': 0,
#  'img_test/fresh_orange_142.jpeg': 0,
#  'img_test/fresh_orange_143.jpeg': 0,
#  'img_test/fresh_orange_144.jpeg': 0,
#  'img_test/fresh_orange_145.jpeg': 0,
#  'img_test/fresh_orange_146.jpeg': 0,
#  'img_test/fresh_orange_147.jpeg': 0,
#  'img_test/fresh_orange_148.jpeg': 0,
#  'img_test/fresh_orange_149.jpeg': 0,
#  'img_test/fresh_orange_15.jpeg': 0,
#  'img_test/fresh_orange_150.jpeg': 0,
#  'img_test/fresh_orange_151.jpeg': 0,
#  'img_test/fresh_orange_152.jpeg': 0,
#  'img_test/fresh_orange_153.jpeg': 0,
#  'img_test/fresh_orange_154.jpeg': 0,
#  'img_test/fresh_orange_155.jpeg': 0,
#  'img_test/fresh_orange_156.jpeg': 0,
#  'img_test/fresh_orange_157.jpeg': 0,
#  'img_test/fresh_orange_158.jpeg': 0,
#  'img_test/fresh_orange_159.jpeg': 0,
#  'img_test/fresh_orange_16.jpeg': 0,
#  'img_test/fresh_orange_160.jpeg': 0,
#  'img_test/fresh_orange_161.jpeg': 0,
#  'img_test/fresh_orange_162.jpeg': 0,
#  'img_test/fresh_orange_163.jpeg': 0,
#  'img_test/fresh_orange_164.jpeg': 0,
#  'img_test/fresh_orange_165.jpeg': 0,
#  'img_test/fresh_orange_166.jpeg': 0,
#  'img_test/fresh_orange_167.jpeg': 0,
#  'img_test/fresh_orange_168.jpeg': 0,
#  'img_test/fresh_orange_169.jpeg': 0,
#  'img_test/fresh_orange_17.jpeg': 0,
#  'img_test/fresh_orange_170.jpeg': 0,
#  'img_test/fresh_orange_171.jpeg': 0,
#  'img_test/fresh_orange_172.jpeg': 0,
#  'img_test/fresh_orange_173.jpeg': 0,
#  'img_test/fresh_orange_174.jpeg': 0,
#  'img_test/fresh_orange_175.jpeg': 0,
#  'img_test/fresh_orange_176.jpeg': 0,
#  'img_test/fresh_orange_177.jpeg': 0,
#  'img_test/fresh_orange_178.jpeg': 0,
#  'img_test/fresh_orange_179.jpeg': 0,
#  'img_test/fresh_orange_18.jpeg': 0,
#  'img_test/fresh_orange_180.jpeg': 0,
#  'img_test/fresh_orange_181.jpeg': 0,
#  'img_test/fresh_orange_182.jpeg': 0,
#  'img_test/fresh_orange_183.jpeg': 0,
#  'img_test/fresh_orange_184.jpeg': 0,
#  'img_test/fresh_orange_185.jpeg': 0,
#  'img_test/fresh_orange_186.jpeg': 0,
#  'img_test/fresh_orange_187.jpeg': 0,
#  'img_test/fresh_orange_188.jpeg': 0,
#  'img_test/fresh_orange_189.jpeg': 0,
#  'img_test/fresh_orange_19.jpeg': 0,
#  'img_test/fresh_orange_190.jpeg': 0,
#  'img_test/fresh_orange_191.jpeg': 0,
#  'img_test/fresh_orange_192.jpeg': 0,
#  'img_test/fresh_orange_193.jpeg': 0,
#  'img_test/fresh_orange_194.jpeg': 0,
#  'img_test/fresh_orange_195.jpeg': 0,
#  'img_test/fresh_orange_196.jpeg': 1,
#  'img_test/fresh_orange_197.jpeg': 0,
#  'img_test/fresh_orange_198.jpeg': 0,
#  'img_test/fresh_orange_199.jpeg': 0,
#  'img_test/fresh_orange_2.jpeg': 0,
#  'img_test/fresh_orange_20.jpeg': 0,
#  'img_test/fresh_orange_200.jpeg': 0,
#  'img_test/fresh_orange_201.jpeg': 0,
#  'img_test/fresh_orange_202.jpeg': 0,
#  'img_test/fresh_orange_203.jpeg': 0,
#  'img_test/fresh_orange_204.jpeg': 0,
#  'img_test/fresh_orange_205.jpeg': 0,
#  'img_test/fresh_orange_206.jpeg': 0,
#  'img_test/fresh_orange_207.jpeg': 0,
#  'img_test/fresh_orange_208.jpeg': 0,
#  'img_test/fresh_orange_209.jpeg': 0,
#  'img_test/fresh_orange_21.jpeg': 0,
#  'img_test/fresh_orange_210.jpeg': 0,
#  'img_test/fresh_orange_211.jpeg': 0,
#  'img_test/fresh_orange_213.jpeg': 0,
#  'img_test/fresh_orange_214.jpeg': 0,
#  'img_test/fresh_orange_215.jpeg': 0,
#  'img_test/fresh_orange_216.jpeg': 0,
#  'img_test/fresh_orange_217.jpeg': 0,
#  'img_test/fresh_orange_218.jpeg': 0,
#  'img_test/fresh_orange_219.jpeg': 0,
#  'img_test/fresh_orange_22.jpeg': 1,
#  'img_test/fresh_orange_220.jpeg': 0,
#  'img_test/fresh_orange_221.jpeg': 0,
#  'img_test/fresh_orange_222.jpeg': 0,
#  'img_test/fresh_orange_223.jpeg': 0,
#  'img_test/fresh_orange_224.jpg': 0,
#  'img_test/fresh_orange_23.jpeg': 0,
#  'img_test/fresh_orange_233.jpeg': 0,
#  'img_test/fresh_orange_234.jpeg': 0,
#  'img_test/fresh_orange_235.jpeg': 0,
#  'img_test/fresh_orange_236.jpeg': 0,
#  'img_test/fresh_orange_237.jpeg': 0,
#  'img_test/fresh_orange_238.jpeg': 0,
#  'img_test/fresh_orange_239.jpeg': 0,
#  'img_test/fresh_orange_24.jpeg': 0,
#  'img_test/fresh_orange_240.jpeg': 0,
#  'img_test/fresh_orange_241.jpeg': 0,
#  'img_test/fresh_orange_242.jpeg': 0,
#  'img_test/fresh_orange_243.jpeg': 0,
#  'img_test/fresh_orange_244.jpeg': 0,
#  'img_test/fresh_orange_245.jpeg': 0,
#  'img_test/fresh_orange_246.jpeg': 0,
#  'img_test/fresh_orange_247.jpeg': 0,
#  'img_test/fresh_orange_248.jpeg': 0,
#  'img_test/fresh_orange_249.jpeg': 0,
#  'img_test/fresh_orange_25.jpeg': 0,
#  'img_test/fresh_orange_250.jpeg': 0,
#  'img_test/fresh_orange_251.jpeg': 0,
#  'img_test/fresh_orange_252.jpeg': 0,
#  'img_test/fresh_orange_253.jpeg': 0,
#  'img_test/fresh_orange_254.jpeg': 0,
#  'img_test/fresh_orange_255.jpeg': 0,
#  'img_test/fresh_orange_256.jpeg': 0,
#  'img_test/fresh_orange_257.jpeg': 0,
#  'img_test/fresh_orange_258.jpeg': 0,
#  'img_test/fresh_orange_259.jpeg': 0,
#  'img_test/fresh_orange_26.jpeg': 0,
#  'img_test/fresh_orange_260.jpeg': 0,
#  'img_test/fresh_orange_261.jpeg': 0,
#  'img_test/fresh_orange_262.jpeg': 0,
#  'img_test/fresh_orange_263.jpeg': 0,
#  'img_test/fresh_orange_264.jpeg': 0,
#  'img_test/fresh_orange_265.jpeg': 0,
#  'img_test/fresh_orange_266.jpeg': 0,
#  'img_test/fresh_orange_267.jpeg': 0,
#  'img_test/fresh_orange_268.jpeg': 0,
#  'img_test/fresh_orange_269.jpeg': 0,
#  'img_test/fresh_orange_27.jpeg': 0,
#  'img_test/fresh_orange_270.jpeg': 0,
#  'img_test/fresh_orange_271.jpeg': 0,
#  'img_test/fresh_orange_272.jpeg': 0,
#  'img_test/fresh_orange_273.jpeg': 0,
#  'img_test/fresh_orange_274.jpeg': 0,
#  'img_test/fresh_orange_275.jpeg': 0,
#  'img_test/fresh_orange_276.jpeg': 0,
#  'img_test/fresh_orange_277.jpeg': 0,
#  'img_test/fresh_orange_278.jpeg': 0,
#  'img_test/fresh_orange_279.jpeg': 0,
#  'img_test/fresh_orange_28.jpeg': 0,
#  'img_test/fresh_orange_280.jpeg': 0,
#  'img_test/fresh_orange_281.jpeg': 0,
#  'img_test/fresh_orange_282.jpeg': 0,
#  'img_test/fresh_orange_283.jpeg': 0,
#  'img_test/fresh_orange_284.jpeg': 0,
#  'img_test/fresh_orange_285.jpeg': 0,
#  'img_test/fresh_orange_286.jpeg': 0,
#  'img_test/fresh_orange_287.jpeg': 0,
#  'img_test/fresh_orange_288.jpeg': 0,
#  'img_test/fresh_orange_289.jpeg': 0,
#  'img_test/fresh_orange_29.jpeg': 0,
#  'img_test/fresh_orange_290.jpeg': 0,
#  'img_test/fresh_orange_291.jpeg': 0,
#  'img_test/fresh_orange_292.jpeg': 0,
#  'img_test/fresh_orange_293.jpeg': 0,
#  'img_test/fresh_orange_294.jpeg': 0,
#  'img_test/fresh_orange_295.jpeg': 0,
#  'img_test/fresh_orange_296.jpeg': 0,
#  'img_test/fresh_orange_297.jpeg': 0,
#  'img_test/fresh_orange_298.jpeg': 0,
#  'img_test/fresh_orange_299.jpeg': 0,
#  'img_test/fresh_orange_3.jpeg': 0,
#  'img_test/fresh_orange_30.jpeg': 0,
#  'img_test/fresh_orange_300.jpeg': 0,
#  'img_test/fresh_orange_301.jpeg': 0,
#  'img_test/fresh_orange_302.jpeg': 0,
#  'img_test/fresh_orange_303.jpeg': 0,
#  'img_test/fresh_orange_304.jpeg': 0,
#  'img_test/fresh_orange_305.jpeg': 0,
#  'img_test/fresh_orange_306.jpeg': 0,
#  'img_test/fresh_orange_307.jpeg': 0,
#  'img_test/fresh_orange_308.jpeg': 0,
#  'img_test/fresh_orange_309.jpeg': 0,
#  'img_test/fresh_orange_31.jpeg': 0,
#  'img_test/fresh_orange_310.jpeg': 0,
#  'img_test/fresh_orange_311.jpeg': 0,
#  'img_test/fresh_orange_312.jpeg': 0,
#  'img_test/fresh_orange_313.jpeg': 0,
#  'img_test/fresh_orange_314.jpeg': 0,
#  'img_test/fresh_orange_315.jpeg': 0,
#  'img_test/fresh_orange_316.jpeg': 0,
#  'img_test/fresh_orange_317.jpeg': 0,
#  'img_test/fresh_orange_318.jpeg': 0,
#  'img_test/fresh_orange_319.jpeg': 0,
#  'img_test/fresh_orange_32.jpeg': 0,
#  'img_test/fresh_orange_320.jpeg': 0,
#  'img_test/fresh_orange_321.jpeg': 0,
#  'img_test/fresh_orange_322.jpeg': 0,
#  'img_test/fresh_orange_323.jpeg': 0,
#  'img_test/fresh_orange_324.jpeg': 0,
#  'img_test/fresh_orange_325.jpeg': 0,
#  'img_test/fresh_orange_326.jpeg': 0,
#  'img_test/fresh_orange_327.jpeg': 0,
#  'img_test/fresh_orange_328.jpeg': 0,
#  'img_test/fresh_orange_329.jpeg': 0,
#  'img_test/fresh_orange_33.jpeg': 0,
#  'img_test/fresh_orange_330.jpeg': 0,
#  'img_test/fresh_orange_331.jpeg': 0,
#  'img_test/fresh_orange_332.jpeg': 0,
#  'img_test/fresh_orange_333.jpeg': 0,
#  'img_test/fresh_orange_334.jpeg': 0,
#  'img_test/fresh_orange_335.jpeg': 0,
#  'img_test/fresh_orange_336.jpeg': 0,
#  'img_test/fresh_orange_337.jpeg': 0,
#  'img_test/fresh_orange_338.jpeg': 0,
#  'img_test/fresh_orange_339.jpeg': 0,
#  'img_test/fresh_orange_34.jpeg': 0,
#  'img_test/fresh_orange_340.jpeg': 0,
#  'img_test/fresh_orange_341.jpeg': 0,
#  'img_test/fresh_orange_342.jpeg': 0,
#  'img_test/fresh_orange_343.jpeg': 0,
#  'img_test/fresh_orange_344.jpeg': 0,
#  'img_test/fresh_orange_345.jpeg': 0,
#  'img_test/fresh_orange_346.jpeg': 0,
#  'img_test/fresh_orange_347.jpeg': 0,
#  'img_test/fresh_orange_348.jpeg': 0,
#  'img_test/fresh_orange_349.jpeg': 0,
#  'img_test/fresh_orange_35.jpeg': 0,
#  'img_test/fresh_orange_350.jpeg': 0,
#  'img_test/fresh_orange_351.jpeg': 0,
#  'img_test/fresh_orange_352.jpeg': 0,
#  'img_test/fresh_orange_353.jpeg': 0,
#  'img_test/fresh_orange_354.jpeg': 0,
#  'img_test/fresh_orange_355.jpeg': 0,
#  'img_test/fresh_orange_356.jpeg': 0,
#  'img_test/fresh_orange_357.jpeg': 0,
#  'img_test/fresh_orange_358.jpeg': 0,
#  'img_test/fresh_orange_359.jpeg': 0,
#  'img_test/fresh_orange_36.jpeg': 1,
#  'img_test/fresh_orange_360.jfif': 0,
#  'img_test/fresh_orange_361.jpg': 0,
#  'img_test/fresh_orange_362.jpg': 0,
#  'img_test/fresh_orange_363.jpg': 0,
#  'img_test/fresh_orange_364.jpg': 0,
#  'img_test/fresh_orange_365.jpg': 0,
#  'img_test/fresh_orange_366.jpg': 0,
#  'img_test/fresh_orange_367.jfif': 0,
#  'img_test/fresh_orange_368.jpg': 0,
#  'img_test/fresh_orange_369.jpeg': 0,
#  'img_test/fresh_orange_37.jpeg': 0,
#  'img_test/fresh_orange_370.jpg': 0,
#  'img_test/fresh_orange_371.jpg': 0,
#  'img_test/fresh_orange_372.jpg': 0,
#  'img_test/fresh_orange_373.jpg': 0,
#  'img_test/fresh_orange_374.jpg': 0,
#  'img_test/fresh_orange_375.jpg': 0,
#  'img_test/fresh_orange_376.jpg': 0,
#  'img_test/fresh_orange_377.jpg': 0,
#  'img_test/fresh_orange_378.jpg': 0,
#  'img_test/fresh_orange_379.jpg': 0,
#  'img_test/fresh_orange_38.jpeg': 0,
#  'img_test/fresh_orange_380.jpeg': 0,
#  'img_test/fresh_orange_381.jpg': 0,
#  'img_test/fresh_orange_382.jpg': 0,
#  'img_test/fresh_orange_383.jpg': 0,
#  'img_test/fresh_orange_384.jpg': 0,
#  'img_test/fresh_orange_385.jpg': 0,
#  'img_test/fresh_orange_386.jpg': 0,
#  'img_test/fresh_orange_387.jpg': 0,
#  'img_test/fresh_orange_388.jpg': 0,
#  'img_test/fresh_orange_389.jpg': 0,
#  'img_test/fresh_orange_39.jpeg': 0,
#  'img_test/fresh_orange_390.jpg': 0,
#  'img_test/fresh_orange_391.jpeg': 0,
#  'img_test/fresh_orange_392.jpg': 0,
#  'img_test/fresh_orange_393.jpg': 0,
#  'img_test/fresh_orange_394.jpg': 0,
#  'img_test/fresh_orange_395.jpg': 0,
#  'img_test/fresh_orange_396.jpg': 0,
#  'img_test/fresh_orange_397.jpeg': 0,
#  'img_test/fresh_orange_398.jpeg': 0,
#  'img_test/fresh_orange_399.jpeg': 0,
#  'img_test/fresh_orange_4.jpeg': 0,
#  'img_test/fresh_orange_40.jpeg': 0,
#  'img_test/fresh_orange_400.jpeg': 0,
#  'img_test/fresh_orange_401.jpeg': 0,
#  'img_test/fresh_orange_402.jpeg': 0,
#  'img_test/fresh_orange_403.jpeg': 0,
#  'img_test/fresh_orange_41.jpeg': 0,
#  'img_test/fresh_orange_42.jpeg': 0,
#  'img_test/fresh_orange_43.jpeg': 0,
#  'img_test/fresh_orange_44.jpeg': 0,
#  'img_test/fresh_orange_45.jpeg': 0,
#  'img_test/fresh_orange_46.jpeg': 0,
#  'img_test/fresh_orange_47.jpeg': 0,
#  'img_test/fresh_orange_48.jpeg': 0,
#  'img_test/fresh_orange_49.jpeg': 0,
#  'img_test/fresh_orange_5.jpeg': 0,
#  'img_test/fresh_orange_50.jpeg': 0,
#  'img_test/fresh_orange_51.jpeg': 0,
#  'img_test/fresh_orange_52.jpeg': 0,
#  'img_test/fresh_orange_53.jpeg': 0,
#  'img_test/fresh_orange_54.jpeg': 0,
#  'img_test/fresh_orange_55.jpeg': 0,
#  'img_test/fresh_orange_56.jpeg': 0,
#  'img_test/fresh_orange_57.jpeg': 0,
#  'img_test/fresh_orange_58.jpeg': 0,
#  'img_test/fresh_orange_59.jpeg': 0,
#  'img_test/fresh_orange_6.jpeg': 0,
#  'img_test/fresh_orange_60.jpeg': 0,
#  'img_test/fresh_orange_61.jpeg': 0,
#  'img_test/fresh_orange_62.jpeg': 0,
#  'img_test/fresh_orange_63.jpeg': 0,
#  'img_test/fresh_orange_64.jpeg': 0,
#  'img_test/fresh_orange_65.jpeg': 0,
#  'img_test/fresh_orange_66.jpeg': 0,
#  'img_test/fresh_orange_67.jpeg': 0,
#  'img_test/fresh_orange_68.jpeg': 0,
#  'img_test/fresh_orange_69.jpeg': 0,
#  'img_test/fresh_orange_7.jpeg': 0,
#  'img_test/fresh_orange_70.jpeg': 0,
#  'img_test/fresh_orange_71.jpeg': 0,
#  'img_test/fresh_orange_72.jpeg': 0,
#  'img_test/fresh_orange_73.jpeg': 0,
#  'img_test/fresh_orange_74.jpeg': 0,
#  'img_test/fresh_orange_75.jpeg': 0,
#  'img_test/fresh_orange_76.jpeg': 0,
#  'img_test/fresh_orange_77.jpeg': 0,
#  'img_test/fresh_orange_78.jpeg': 0,
#  'img_test/fresh_orange_79.jpeg': 0,
#  'img_test/fresh_orange_8.jpeg': 0,
#  'img_test/fresh_orange_80.jpeg': 0,
#  'img_test/fresh_orange_81.jpeg': 0,
#  'img_test/fresh_orange_82.jpeg': 0,
#  'img_test/fresh_orange_83.jpeg': 0,
#  'img_test/fresh_orange_84.jpeg': 0,
#  'img_test/fresh_orange_85.jpeg': 0,
#  'img_test/fresh_orange_86.jpeg': 0,
#  'img_test/fresh_orange_87.jpeg': 0,
#  'img_test/fresh_orange_88.jpeg': 0,
#  'img_test/fresh_orange_89.jpeg': 0,
#  'img_test/fresh_orange_9.jpeg': 0,
#  'img_test/fresh_orange_90.jpeg': 0,
#  'img_test/fresh_orange_91.jpeg': 0,
#  'img_test/fresh_orange_92.jpeg': 0,
#  'img_test/fresh_orange_93.jpeg': 0,
#  'img_test/fresh_orange_94.jpeg': 0,
#  'img_test/fresh_orange_95.jpeg': 0,
#  'img_test/fresh_orange_96.jpeg': 0,
#  'img_test/fresh_orange_97.jpeg': 0,
#  'img_test/fresh_orange_98.jpeg': 0,
#  'img_test/fresh_orange_99.jpeg': 0,
#  'img_test/fresh_orange_a.jpeg': 0,
#  'img_test/fresh_orange_b.jpg': 0,
#  'img_test/ripe_mango_1.jpg': 0,
#  'img_test/ripe_mango_2.jpg': 0,
#  'img_test/rotten_apple_1.jpg': 0,
#  'img_test/rotten_apple_10.jpg': 0,
#  'img_test/rotten_apple_100.jpeg': 0,
#  'img_test/rotten_apple_101.jpg': 0,
#  'img_test/rotten_apple_102.jpg': 0,
#  'img_test/rotten_apple_103.jpg': 0,
#  'img_test/rotten_apple_104.jpg': 0,
#  'img_test/rotten_apple_105.jpg': 0,
#  'img_test/rotten_apple_106.jpg': 0,
#  'img_test/rotten_apple_107.jpg': 0,
#  'img_test/rotten_apple_108.jpg': 0,
#  'img_test/rotten_apple_109.jpeg': 0,
#  'img_test/rotten_apple_11.jpeg': 0,
#  'img_test/rotten_apple_110.jpeg': 0,
#  'img_test/rotten_apple_111.jpeg': 0,
#  'img_test/rotten_apple_112.jpeg': 0,
#  'img_test/rotten_apple_12.jpeg': 0,
#  'img_test/rotten_apple_13.jpg': 0,
#  'img_test/rotten_apple_14.jpg': 0,
#  'img_test/rotten_apple_15.jpg': 0,
#  'img_test/rotten_apple_16.jpg': 0,
#  'img_test/rotten_apple_17.jpg': 0,
#  'img_test/rotten_apple_19.jpg': 0,
#  'img_test/rotten_apple_2.jpg': 0,
#  'img_test/rotten_apple_20.jpg': 0,
#  'img_test/rotten_apple_21.jpeg': 0,
#  'img_test/rotten_apple_22.jpeg': 0,
#  'img_test/rotten_apple_23.jpeg': 0,
#  'img_test/rotten_apple_24.jpeg': 0,
#  'img_test/rotten_apple_25.jpeg': 0,
#  'img_test/rotten_apple_26.jpeg': 0,
#  'img_test/rotten_apple_27.jpeg': 0,
#  'img_test/rotten_apple_28.jpeg': 0,
#  'img_test/rotten_apple_29.jpeg': 0,
#  'img_test/rotten_apple_3.jpeg': 0,
#  'img_test/rotten_apple_30.jpeg': 0,
#  'img_test/rotten_apple_31.jpeg': 0,
#  'img_test/rotten_apple_32.jpeg': 0,
#  'img_test/rotten_apple_33.jpeg': 0,
#  'img_test/rotten_apple_34.jpeg': 0,
#  'img_test/rotten_apple_35.jpeg': 0,
#  'img_test/rotten_apple_36.jpeg': 0,
#  'img_test/rotten_apple_37.jpeg': 0,
#  'img_test/rotten_apple_38.jpeg': 0,
#  'img_test/rotten_apple_39.jpeg': 0,
#  'img_test/rotten_apple_4.jpeg': 0,
#  'img_test/rotten_apple_40.jpeg': 0,
#  'img_test/rotten_apple_41.jpeg': 0,
#  'img_test/rotten_apple_42.jpeg': 0,
#  'img_test/rotten_apple_43.jpeg': 0,
#  'img_test/rotten_apple_44.jpeg': 1,
#  'img_test/rotten_apple_45.jpeg': 0,
#  'img_test/rotten_apple_46.jpeg': 0,
#  'img_test/rotten_apple_47.jpeg': 0,
#  'img_test/rotten_apple_48.jpeg': 0,
#  'img_test/rotten_apple_49.jpeg': 0,
#  'img_test/rotten_apple_5.jpeg': 0,
#  'img_test/rotten_apple_50.jpeg': 0,
#  'img_test/rotten_apple_51.jpeg': 0,
#  'img_test/rotten_apple_52.jpeg': 0,
#  'img_test/rotten_apple_53.jpeg': 0,
#  'img_test/rotten_apple_54.jpeg': 0,
#  'img_test/rotten_apple_55.jpeg': 0,
#  'img_test/rotten_apple_56.jpeg': 0,
#  'img_test/rotten_apple_57.jpg': 0,
#  'img_test/rotten_apple_58.jpeg': 0,
#  'img_test/rotten_apple_59.jpeg': 0,
#  'img_test/rotten_apple_6.jpeg': 1,
#  'img_test/rotten_apple_60.jpeg': 0,
#  'img_test/rotten_apple_61.jpeg': 0,
#  'img_test/rotten_apple_62.jpeg': 0,
#  'img_test/rotten_apple_63.jpeg': 0,
#  'img_test/rotten_apple_64.jpeg': 0,
#  'img_test/rotten_apple_65.jpeg': 0,
#  'img_test/rotten_apple_66.jpeg': 0,
#  'img_test/rotten_apple_67.jpeg': 0,
#  'img_test/rotten_apple_68.jpeg': 0,
#  'img_test/rotten_apple_69.jpeg': 0,
#  'img_test/rotten_apple_7.jpeg': 0,
#  'img_test/rotten_apple_70.jpeg': 0,
#  'img_test/rotten_apple_71.jpeg': 0,
#  'img_test/rotten_apple_72.jpeg': 0,
#  'img_test/rotten_apple_73.jpeg': 0,
#  'img_test/rotten_apple_74.jpeg': 0,
#  'img_test/rotten_apple_75.jpeg': 0,
#  'img_test/rotten_apple_76.jpeg': 0,
#  'img_test/rotten_apple_77.jpeg': 0,
#  'img_test/rotten_apple_78.jpeg': 0,
#  'img_test/rotten_apple_79.jpeg': 0,
#  'img_test/rotten_apple_8.jpeg': 0,
#  'img_test/rotten_apple_80.jpeg': 0,
#  'img_test/rotten_apple_81.jpeg': 0,
#  'img_test/rotten_apple_82.jpeg': 0,
#  'img_test/rotten_apple_83.jpeg': 0,
#  'img_test/rotten_apple_84.jpeg': 0,
#  'img_test/rotten_apple_85.jpeg': 0,
#  'img_test/rotten_apple_86.jpeg': 0,
#  'img_test/rotten_apple_87.jpeg': 0,
#  'img_test/rotten_apple_88.jpeg': 0,
#  'img_test/rotten_apple_89.jpeg': 0,
#  'img_test/rotten_apple_9.jpg': 0,
#  'img_test/rotten_apple_90.jpeg': 0,
#  'img_test/rotten_apple_91.jpeg': 0,
#  'img_test/rotten_apple_92.jpeg': 0,
#  'img_test/rotten_apple_93.jpeg': 0,
#  'img_test/rotten_apple_94.jpeg': 0,
#  'img_test/rotten_apple_95.jpeg': 1,
#  'img_test/rotten_apple_96.jpeg': 0,
#  'img_test/rotten_apple_97.jpeg': 0,
#  'img_test/rotten_apple_98.jpeg': 0,
#  'img_test/rotten_apple_99.jpeg': 0,
#  'img_test/rotten_apple_a.JPG': 1,
#  'img_test/rotten_apple_b.JPG': 0,
#  'img_test/rotten_banana_a.jpeg': 0,
#  'img_test/rotten_banana_b.JPG': 0,
#  'img_test/rotten_mango_a.jpg': 0,
#  'img_test/rotten_orange_a.jpeg': 0}
