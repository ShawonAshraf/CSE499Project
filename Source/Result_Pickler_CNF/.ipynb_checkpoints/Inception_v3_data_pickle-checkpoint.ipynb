# %%
import os

img_test_dir = "img_test"

# %%
# check if dir is there
if os.path.exists(img_test_dir):
    print("Path exists")
else:
    print("nope")
# Out:
# Path exists

# %%
label_dict = {
    "rotten banana": 0,
    "rotten apple": 1,
    "fresh banana": 2,
    "fresh mango": 3,
    "fresh orange": 4,
    "fresh apple": 5,
    "rotten mango": 6,
    "rotten orange": 7
}

label_dict_no_ws = {
    "rotten_banana": 0,
    "rotten_apple": 1,
    "fresh_banana": 2,
    "fresh_mango": 3,
    "fresh_orange": 4,
    "fresh_apple": 5,
    "rotten_mango": 6,
    "rotten_orange": 7
}

# %%
labels = list(label_dict.keys())
labels
# Out:
# ['fresh mango',
#  'fresh banana',
#  'fresh apple',
#  'fresh orange',
#  'rotten banana',
#  'rotten apple',
#  'rotten mango',
#  'rotten orange']

# %%
# eliminate the whitespace in labels
labels_no_whitespace = []
for label in labels:
    labels_no_whitespace.append(label.replace(" ", "_"))

# %%
labels_no_whitespace
# Out:
# ['fresh_mango',
#  'fresh_banana',
#  'fresh_apple',
#  'fresh_orange',
#  'rotten_banana',
#  'rotten_apple',
#  'rotten_mango',
#  'rotten_orange']

# %%
def get_ground_truth(path):
    images = os.listdir(path)
    print("Total {} images in {}".format(len(images), path))
    
    ground_truth_dict = {}
    
    for img in images:
        for label in labels_no_whitespace:
            if label in img:
                img_path = os.path.join(img_test_dir, img)
                ground_truth_dict[img_path] = label_dict_no_ws[label]
                
    return ground_truth_dict

# %%
ground_truth = get_ground_truth(img_test_dir)
# Out:
# Total 536 images in img_test

# %%
# pickle the ground_truths
import pickle

pickle_dir = "inception_pickled"
pickle_out_file = os.path.join(pickle_dir, "ground_truth.pickle")

gt_pickle_out = open(pickle_out_file, "wb")
pickle.dump(ground_truth, gt_pickle_out)

# %%
# check if pickled properly
pickle_in = pickle.load(open(pickle_out_file, "rb"))
print(pickle_in)
# Out:
# {'img_test/fresh_orange_372.jpg': 4, 'img_test/fresh_orange_134.jpeg': 4, 'img_test/fresh_orange_273.jpeg': 4, 'img_test/fresh_orange_185.jpeg': 4, 'img_test/rotten_apple_59.jpeg': 1, 'img_test/fresh_orange_233.jpeg': 4, 'img_test/fresh_orange_84.jpeg': 4, 'img_test/fresh_orange_300.jpeg': 4, 'img_test/fresh_orange_113.jpeg': 4, 'img_test/fresh_orange_55.jpeg': 4, 'img_test/fresh_orange_193.jpeg': 4, 'img_test/fresh_orange_294.jpeg': 4, 'img_test/rotten_apple_62.jpeg': 1, 'img_test/fresh_orange_180.jpeg': 4, 'img_test/fresh_orange_297.jpeg': 4, 'img_test/rotten_apple_8.jpeg': 1, 'img_test/fresh_orange_292.jpeg': 4, 'img_test/rotten_apple_104.jpg': 1, 'img_test/fresh_orange_153.jpeg': 4, 'img_test/fresh_orange_222.jpeg': 4, 'img_test/fresh_orange_214.jpeg': 4, 'img_test/fresh_orange_89.jpeg': 4, 'img_test/fresh_orange_28.jpeg': 4, 'img_test/fresh_orange_359.jpeg': 4, 'img_test/fresh_orange_354.jpeg': 4, 'img_test/fresh_orange_119.jpeg': 4, 'img_test/fresh_orange_340.jpeg': 4, 'img_test/fresh_orange_339.jpeg': 4, 'img_test/fresh_orange_80.jpeg': 4, 'img_test/fresh_orange_206.jpeg': 4, 'img_test/fresh_orange_202.jpeg': 4, 'img_test/fresh_orange_26.jpeg': 4, 'img_test/fresh_orange_93.jpeg': 4, 'img_test/fresh_orange_154.jpeg': 4, 'img_test/fresh_orange_394.jpg': 4, 'img_test/fresh_orange_143.jpeg': 4, 'img_test/fresh_orange_234.jpeg': 4, 'img_test/fresh_orange_64.jpeg': 4, 'img_test/fresh_orange_246.jpeg': 4, 'img_test/fresh_orange_306.jpeg': 4, 'img_test/rotten_apple_67.jpeg': 1, 'img_test/fresh_orange_385.jpg': 4, 'img_test/fresh_orange_376.jpg': 4, 'img_test/fresh_orange_159.jpeg': 4, 'img_test/rotten_apple_33.jpeg': 1, 'img_test/fresh_orange_309.jpeg': 4, 'img_test/rotten_apple_14.jpg': 1, 'img_test/fresh_orange_145.jpeg': 4, 'img_test/fresh_orange_208.jpeg': 4, 'img_test/fresh_orange_20.jpeg': 4, 'img_test/fresh_orange_179.jpeg': 4, 'img_test/fresh_orange_374.jpg': 4, 'img_test/fresh_orange_128.jpeg': 4, 'img_test/fresh_orange_47.jpeg': 4, 'img_test/fresh_orange_168.jpeg': 4, 'img_test/rotten_apple_5.jpeg': 1, 'img_test/fresh_orange_32.jpeg': 4, 'img_test/fresh_orange_213.jpeg': 4, 'img_test/fresh_orange_1.jpeg': 4, 'img_test/rotten_apple_71.jpeg': 1, 'img_test/fresh_orange_279.jpeg': 4, 'img_test/rotten_apple_110.jpeg': 1, 'img_test/fresh_orange_6.jpeg': 4, 'img_test/rotten_apple_53.jpeg': 1, 'img_test/fresh_orange_182.jpeg': 4, 'img_test/fresh_orange_352.jpeg': 4, 'img_test/rotten_apple_60.jpeg': 1, 'img_test/fresh_orange_348.jpeg': 4, 'img_test/fresh_orange_321.jpeg': 4, 'img_test/fresh_mango_e.jpg': 3, 'img_test/fresh_orange_264.jpeg': 4, 'img_test/rotten_apple_85.jpeg': 1, 'img_test/fresh_orange_194.jpeg': 4, 'img_test/rotten_apple_37.jpeg': 1, 'img_test/fresh_orange_188.jpeg': 4, 'img_test/fresh_orange_285.jpeg': 4, 'img_test/rotten_apple_84.jpeg': 1, 'img_test/fresh_orange_284.jpeg': 4, 'img_test/fresh_orange_349.jpeg': 4, 'img_test/fresh_orange_298.jpeg': 4, 'img_test/fresh_orange_378.jpg': 4, 'img_test/rotten_apple_81.jpeg': 1, 'img_test/fresh_orange_10.jpeg': 4, 'img_test/rotten_apple_93.jpeg': 1, 'img_test/rotten_apple_112.jpeg': 1, 'img_test/fresh_orange_280.jpeg': 4, 'img_test/rotten_apple_70.jpeg': 1, 'img_test/fresh_orange_176.jpeg': 4, 'img_test/fresh_orange_364.jpg': 4, 'img_test/fresh_orange_291.jpeg': 4, 'img_test/fresh_orange_190.jpeg': 4, 'img_test/fresh_orange_88.jpeg': 4, 'img_test/fresh_orange_16.jpeg': 4, 'img_test/fresh_orange_381.jpg': 4, 'img_test/fresh_orange_259.jpeg': 4, 'img_test/fresh_orange_386.jpg': 4, 'img_test/fresh_orange_111.jpeg': 4, 'img_test/fresh_orange_82.jpeg': 4, 'img_test/rotten_apple_76.jpeg': 1, 'img_test/fresh_orange_162.jpeg': 4, 'img_test/fresh_orange_235.jpeg': 4, 'img_test/rotten_apple_100.jpeg': 1, 'img_test/rotten_apple_57.jpg': 1, 'img_test/fresh_orange_362.jpg': 4, 'img_test/fresh_orange_333.jpeg': 4, 'img_test/fresh_orange_276.jpeg': 4, 'img_test/fresh_orange_338.jpeg': 4, 'img_test/fresh_orange_92.jpeg': 4, 'img_test/fresh_orange_78.jpeg': 4, 'img_test/fresh_orange_1 ...

# %%
# now for classification

import tensorflow as tf

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

def classify(image_path):
    # Read in the image_data
    image_data = tf.gfile.FastGFile(image_path, 'rb').read()

    # Loads label file, strips off carriage return
    label_lines = [line.rstrip() for line
                   in tf.gfile.GFile("retrained_labels.txt")]

    # label_names = label_lines

    # Unpersists graph from file
    with tf.gfile.FastGFile("retrained_graph.pb", 'rb') as f:
        graph_def = tf.GraphDef()
        graph_def.ParseFromString(f.read())
        tf.import_graph_def(graph_def, name='')

    with tf.Session() as sess:
        # Feed the image_data as input to the graph and get first prediction
        softmax_tensor = sess.graph.get_tensor_by_name('final_result:0')

        predictions = sess.run(softmax_tensor, \
                               {'DecodeJpeg/contents:0': image_data})

        # global_pred = predictions

        # Sort to show labels of first prediction in order of confidence
        top_k = predictions[0].argsort()[-len(predictions[0]):][::-1]
        # label_id = top_k

        
        print('Processing {} ...................DONE'.format(image_path))
        resultDict = {}
        for node_id in top_k:
            human_string = label_lines[node_id]
            score = predictions[0][node_id]
#              print('Category : {} \nScore = {} %'.format(human_string, score * 100))

            resultDict[human_string] = score
        
        #print('Category : {}\tScore : {}'.format(label_lines[node_id], predictions[0][node_id]))

        #print('\nDONE===========================', end='\n')
        
        return resultDict

# %%
image_dir = img_test_dir

images = os.listdir(image_dir)
label_lines = [line.rstrip() for line
                   in tf.gfile.GFile("retrained_labels.txt")]
pred_dict = {}
    
# create graph
# with tf.gfile.FastGFile("retrained_graph.pb", 'rb') as f:
#     graph_def = tf.GraphDef()
#     graph_def.ParseFromString(f.read())
#     tf.import_graph_def(graph_def, name='')
    
def create_graph():
  """Creates a graph from saved GraphDef file and returns a saver."""
  # Creates graph from saved graph_def.pb.
  with tf.gfile.FastGFile("retrained_graph.pb", 'rb') as f:
    graph_def = tf.GraphDef()
    graph_def.ParseFromString(f.read())
    _ = tf.import_graph_def(graph_def, name='')

# %%
# def run_inference(img_dir):
#     create_graph()
    
#     pred_dict = {}
    
#     for image in images:
#         image = os.path.join(image_dir, image)
#         image_data = tf.gfile.FastGFile(image, 'rb').read()
        
#         with tf.Session() as sess:
#             # Feed the image_data as input to the graph and get first prediction
#             softmax_tensor = sess.graph.get_tensor_by_name('final_result:0')

#             predictions = sess.run(softmax_tensor, \
#                                     {'DecodeJpeg/contents:0': image_data})


#             # Sort to show labels of first prediction in order of confidence
#             top_k = predictions[0].argsort()[-len(predictions[0]):][::-1]
#             # label_id = top_k

        
#             print('Processing {} ...................DONE'.format(image))
#             resultDict = {}
#             for node_id in top_k:
#                 human_string = label_lines[node_id]
#                 score = predictions[0][node_id]
                
#                 resultDict[human_string] = score
                
#         # get max score
#         maxKey = max(rDict.keys(), key=(lambda k: rDict[k]))
#         pred_dict[image] = label_dict_no_ws[maxKey]
        
#         return pred_dict

# %%
def run_inference(img_dir):
    create_graph()
    
    pred_dict = {}
        
    with tf.Session() as sess:
        softmax_tensor = sess.graph.get_tensor_by_name('final_result:0')
        for image in images:
            image = os.path.join(image_dir, image)
            image_data = tf.gfile.FastGFile(image, 'rb').read()
                # Feed the image_data as input to the graph and get first prediction
            

            predictions = sess.run(softmax_tensor, \
                                        {'DecodeJpeg/contents:0': image_data})


                # Sort to show labels of first prediction in order of confidence
            top_k = predictions[0].argsort()[-len(predictions[0]):][::-1]
                # label_id = top_k

        
            print('Processing {} ...................DONE'.format(image))
            resultDict = {}
            for node_id in top_k:
                human_string = label_lines[node_id]
                score = predictions[0][node_id]
                
                resultDict[human_string] = score
                
            # get max score
            maxKey = max(resultDict.keys(), key=(lambda k: resultDict[k]))
            pred_dict[image] = label_dict[maxKey]
        
    return pred_dict

# %%
d = run_inference(img_dir=img_test_dir)
# Out:
# Processing img_test/fresh_orange_316.jpeg ...................DONE
# Processing img_test/fresh_apple_a.jpg ...................DONE
# Processing img_test/fresh_apple_b.jpg ...................DONE
# Processing img_test/fresh_apple_c.JPG ...................DONE
# Processing img_test/fresh_banana_a.jpg ...................DONE
# Processing img_test/fresh_mango_a.jpg ...................DONE
# Processing img_test/fresh_mango_b.jpg ...................DONE
# Processing img_test/fresh_mango_c.jpg ...................DONE
# Processing img_test/fresh_mango_d.jpg ...................DONE
# Processing img_test/fresh_mango_e.jpg ...................DONE
# Processing img_test/fresh_mango_f.jpg ...................DONE
# Processing img_test/fresh_orange_1.jpeg ...................DONE
# Processing img_test/fresh_orange_10.jpeg ...................DONE
# Processing img_test/fresh_orange_100.jpeg ...................DONE
# Processing img_test/fresh_orange_101.jpeg ...................DONE
# Processing img_test/fresh_orange_102.jpeg ...................DONE
# Processing img_test/fresh_orange_103.jpeg ...................DONE
# Processing img_test/fresh_orange_105.jpeg ...................DONE
# Processing img_test/fresh_orange_106.jpeg ...................DONE
# Processing img_test/fresh_orange_107.jpeg ...................DONE
# Processing img_test/fresh_orange_108.jpeg ...................DONE
# Processing img_test/fresh_orange_109.jpeg ...................DONE
# Processing img_test/fresh_orange_11.jpeg ...................DONE
# Processing img_test/fresh_orange_110.jpeg ...................DONE
# Processing img_test/fresh_orange_111.jpeg ...................DONE
# Processing img_test/fresh_orange_112.jpeg ...................DONE
# Processing img_test/fresh_orange_113.jpeg ...................DONE
# Processing img_test/fresh_orange_114.jpeg ...................DONE
# Processing img_test/fresh_orange_115.jpeg ...................DONE
# Processing img_test/fresh_orange_116.jpeg ...................DONE
# Processing img_test/fresh_orange_117.jpeg ...................DONE
# Processing img_test/fresh_orange_118.jpeg ...................DONE
# Processing img_test/fresh_orange_12.jpeg ...................DONE
# Processing img_test/fresh_orange_120.jpeg ...................DONE
# Processing img_test/fresh_orange_121.jpeg ...................DONE
# Processing img_test/fresh_orange_122.jpeg ...................DONE
# Processing img_test/fresh_orange_123.jpeg ...................DONE
# Processing img_test/fresh_orange_124.jpeg ...................DONE
# Processing img_test/fresh_orange_125.jpeg ...................DONE
# Processing img_test/fresh_orange_126.jpeg ...................DONE
# Processing img_test/fresh_orange_127.jpeg ...................DONE
# Processing img_test/fresh_orange_128.jpeg ...................DONE
# Processing img_test/fresh_orange_129.jpeg ...................DONE
# Processing img_test/fresh_orange_13.jpeg ...................DONE
# Processing img_test/fresh_orange_130.jpeg ...................DONE
# Processing img_test/fresh_orange_131.jpeg ...................DONE
# Processing img_test/fresh_orange_132.jpeg ...................DONE
# Processing img_test/fresh_orange_134.jpeg ...................DONE
# Processing img_test/fresh_orange_135.jpeg ...................DONE
# Processing img_test/fresh_orange_136.jpeg ...................DONE
# Processing img_test/fresh_orange_137.jpeg ...................DONE
# Processing img_test/fresh_orange_138.jpeg ...................DONE
# Processing img_test/fresh_orange_139.jpeg ...................DONE
# Processing img_test/fresh_orange_14.jpeg ...................DONE
# Processing img_test/fresh_orange_140.jpeg ...................DONE
# Processing img_test/fresh_orange_141.jpeg ...................DONE
# Processing img_test/fresh_orange_142.jpeg ...................DONE
# Processing img_test/fresh_orange_143.jpeg ...................DONE
# Processing img_test/fresh_orange_144.jpeg ...................DONE
# Processing img_test/fresh_orange_145.jpeg ...................DONE
# Processing img_test/fresh_orange_146.jpeg ...................DONE
# Processing img_test/fresh_orange_147.jpeg ...................DONE
# Processing img_test/fresh_orange_104.jpeg ...................DONE
# Processing img_test/fresh_orange_119.jpeg ...................DONE
# Processing img_test/fresh_orange_133.jpeg ...................DONE
# Processing img_test/fresh_orange_148.jpeg ...................DONE
# Processing img_test/fresh_orange_162.jpeg ...................DONE
# Processing img_test/fresh_orange_177.jpeg ...................DONE
# Processing img_test/fresh_orange_191.jpeg ...................DONE
# Processing img_test/fresh_orange_206.jpeg ...................DONE
# Processing img_test/fresh_orange_221.jpeg ...................DONE
# Processing img_test/fresh_orange_243.jpeg ...................DONE
# Processing img_test/fresh_orange_258.jpeg ...................DONE
# Processing img_test/fresh_orange_272.jpeg ...................DONE
# Processing img_test/fresh_orange_287.jpeg ...................DONE
# Processing img_test/fresh_orange_301.jpeg ...................DONE
# Processing img_test/fresh_orange_149.jpeg ...................DONE
# Processing img_test/fresh_orange_15.jpeg ...................DONE
# Processing img_test/fresh_orange_150.jpeg ...................DONE
# Processing img_test/fresh_orange_151.jpeg ...................DONE
# Processing img_test/fresh_orange_152.jpeg ...................DONE
# Processing img_test/fresh_orange_153.jpeg ...................DONE
# Processing img_test/fresh_orange_154.jpeg ...................DONE
# Processing img_test/fresh_orange_155.jpeg ...................DONE
# Processing img_test/fresh_orange_156.jpeg ...................DONE
# Processing img_test/fresh_orange_157.jpeg ...................DONE
# Processing img_test/fresh_orange_158.jpeg ...................DONE
# Processing img_test/fresh_orange_159.jpeg ...................DONE
# Processing img_test/fresh_orange_16.jpeg ...................DONE
# Processing img_test/fresh_orange_160.jpeg ...................DONE
# Processing img_test/fresh_orange_161.jpeg ...................DONE
# Processing img_test/fresh_orange_163.jpeg ...................DONE
# Processing img_test/fresh_orange_164.jpeg ...................DONE
# Processing img_test/fresh_orange_165.jpeg ...................DONE
# Processing img_test/fresh_orange_166.jpeg ...................DONE
# Processing img_test/fresh_orange_167.jpeg ...................DONE
# Processing img_test/fresh_orange_168.jpeg ...................DONE
# Processing img_test/fresh_orange_169.jpeg ...................DONE
# Processing img_test/fresh_orange_17.jpeg ...................DONE
# Processing img_test/fresh_orange_170.jpeg ...................DONE
# Processing img_test/fresh_orange_171.jpeg ...................DONE
# Processing img_test/fresh_orange_172.jpeg ...................DONE
# Processing img_test/fresh_orange_173.jpeg ...................DONE
# Processing img_test/fresh_orange_174.jpeg ...................DONE
# Processing img_test/fresh_orange_175.jpeg ...................DONE
# Processing img_test/fresh_orange_176.jpeg ...................DONE
# Processing img_test/fresh_orange_178.jpeg ...................DONE
# Processing img_test/fresh_orange_179.jpeg ...................DONE
# Processing img_test/fresh_orange_18.jpeg ...................DONE
# Processing img_test/fresh_orange_180.jpeg ...................DONE
# Processing img_test/fresh_orange_181.jpeg ...................DONE
# Processing img_test/fresh_orange_182.jpeg ...................DONE
# Processing img_test/fresh_orange_183.jpeg ...................DONE
# Processing img_test/fresh_orange_184.jpeg ...................DONE
# Processing img_test/fresh_orange_185.jpeg ...................DONE
# Processing img_test/fresh_orange_186.jpeg ...................DONE
# Processing img_test/fresh_orange_187.jpeg ...................DONE
# Processing img_test/fresh_orange_188.jpeg ...................DONE
# Processing img_test/fresh_orange_189.jpeg ...................DONE
# Processing img_test/fresh_orange_19.jpeg ...................DONE
# Processing img_test/fresh_orange_190.jpeg ...................DONE
# Processing img_test/fresh_orange_192.jpeg ...................DONE
# Processing img_test/fresh_orange_193.jpeg ...................DONE
# Processing img_test/fresh_orange_194.jpeg ...................DONE
# Processing img_test/fresh_orange_195.jpeg ...................DONE
# Processing img_test/fresh_orange_196.jpeg ...................DONE
# Processing img_test/fresh_orange_197.jpeg ...................DONE
# Processing img_test/fresh_orange_198.jpeg ...................DONE
# Processing img_test/fresh_orange_199.jpeg ...................DONE
# Processing img_test/fresh_orange_2.jpeg ...................DONE
# Processing img_test/fresh_orange_20.jpeg ...................DONE
# Processing img_test/fresh_orange_200.jpeg ...................DONE
# Processing img_test/fresh_orange_201.jpeg ...................DONE
# Processing img_test/fresh_orange_202.jpeg ...................DONE
# Processing img_test/fresh_orange_203.jpeg ...................DONE
# Processing img_test/fresh_orange_204.jpeg ...................DONE
# Processing img_test/fresh_orange_205.jpeg ...................DONE
# Processing img_test/fresh_orange_207.jpeg ...................DONE
# Processing img_test/fresh_orange_208.jpeg ...................DONE
# Processing img_test/fresh_orange_209.jpeg ...................DONE
# Processing img_test/fresh_orange_21.jpeg ...................DONE
# Processing img_test/fresh_orange_210.jpeg ...................DONE
# Processing img_test/fresh_orange_211.jpeg ...................DONE
# Processing img_test/fresh_orange_213.jpeg ...................DONE
# Processing img_test/fresh_orange_214.jpeg ...................DONE
# Processing img_test/fresh_orange_215.jpeg ...................DONE
# Processing img_test/fresh_orange_216.jpeg ...................DONE
# Processing img_test/fresh_orange_217.jpeg ...................DONE
# Processing img_test/fresh_orange_218.jpeg ...................DONE
# Processing img_test/fresh_orange_219.jpeg ...................DONE
# Processing img_test/fresh_orange_22.jpeg ...................DONE
# Processing img_test/fresh_orange_220.jpeg ...................DONE
# Processing img_test/fresh_orange_222.jpeg ...................DONE
# Processing img_test/fresh_orange_223.jpeg ...................DONE
# Processing img_test/fresh_orange_224.jpg ...................DONE
# Processing img_test/fresh_orange_23.jpeg ...................DONE
# Processing img_test/fresh_orange_233.jpeg ...................DONE
# Processing img_test/fresh_orange_234.jpeg ...................DONE
# Processing img_test/fresh_orange_235.jpeg ...................DONE
# Processing img_test/fresh_orange_236.jpeg ...................DONE
# Processing img_test/fresh_orange_237.jpeg ...................DONE
# Processing img_test/fresh_orange_238.jpeg ...................DONE
# Processing img_test/fresh_orange_239.jpeg ...................DONE
# Processing img_test/fresh_orange_24.jpeg ...................DONE
# Processing img_test/fresh_orange_240.jpeg ...................DONE
# Processing img_test/fresh_orange_241.jpeg ...................DONE
# Processing img_test/fresh_orange_242.jpeg ...................DONE
# Processing img_test/fresh_orange_244.jpeg ...................DONE
# Processing img_test/fresh_orange_245.jpeg ...................DONE
# Processing img_test/fresh_orange_246.jpeg ...................DONE
# Processing img_test/fresh_orange_247.jpeg ...................DONE
# Processing img_test/fresh_orange_248.jpeg ...................DONE
# Processing img_test/fresh_orange_249.jpeg ...................DONE
# Processing img_test/fresh_orange_25.jpeg ...................DONE
# Processing img_test/fresh_orange_250.jpeg ...................DONE
# Processing img_test/fresh_orange_251.jpeg ...................DONE
# Processing img_test/fresh_orange_252.jpeg ...................DONE
# Processing img_test/fresh_orange_253.jpeg ...................DONE
# Processing img_test/fresh_orange_254.jpeg ...................DONE
# Processing img_test/fresh_orange_255.jpeg ...................DONE
# Processing img_test/fresh_orange_256.jpeg ...................DONE
# Processing img_test/fresh_orange_257.jpeg ...................DONE
# Processing img_test/fresh_orange_259.jpeg ...................DONE
# Processing img_test/fresh_orange_26.jpeg ...................DONE
# Processing img_test/fresh_orange_260.jpeg ...................DONE
# Processing img_test/fresh_orange_261.jpeg ...................DONE
# Processing img_test/fresh_orange_262.jpeg ...................DONE
# Processing img_test/fresh_orange_263.jpeg ...................DONE
# Processing img_test/fresh_orange_264.jpeg ...................DONE
# Processing img_test/fresh_orange_265.jpeg ...................DONE
# Processing img_test/fresh_orange_266.jpeg ...................DONE
# Processing img_test/fresh_orange_267.jpeg ...................DONE
# Processing img_test/fresh_orange_268.jpeg ...................DONE
# Processing img_test/fresh_orange_269.jpeg ...................DONE
# Processing img_test/fresh_orange_27.jpeg ...................DONE
# Processing img_test/fresh_orange_270.jpeg ...................DONE
# Processing img_test/fresh_orange_271.jpeg ...................DONE
# Processing img_test/fresh_orange_273.jpeg ...................DONE
# Processing img_test/fresh_orange_274.jpeg ...................DONE
# Processing img_test/fresh_orange_275.jpeg ...................DONE
# Processing img_test/fresh_orange_276.jpeg ...................DONE
# Processing img_test/fresh_orange_277.jpeg ...................DONE
# Processing img_test/fresh_orange_278.jpeg ...................DONE
# Processing img_test/fresh_orange_279.jpeg ...................DONE
# Processing img_test/fresh_orange_28.jpeg ...................DONE
# Processing img_test/fresh_orange_280.jpeg ...................DONE
# Processing img_test/fresh_orange_281.jpeg ...................DONE
# Processing img_test/fresh_orange_282.jpeg ...................DONE
# Processing img_test/fresh_orange_283.jpeg ...................DONE
# Processing img_test/fresh_orange_284.jpeg ...................DONE
# Processing img_test/fresh_orange_285.jpeg ...................DONE
# Processing img_test/fresh_orange_286.jpeg ...................DONE
# Processing img_test/fresh_orange_288.jpeg ...................DONE
# Processing img_test/fresh_orange_289.jpeg ...................DONE
# Processing img_test/fresh_orange_29.jpeg ...................DONE
# Processing img_test/fresh_orange_290.jpeg ...................DONE
# Processing img_test/fresh_orange_291.jpeg ...................DONE
# Processing img_test/fresh_orange_292.jpeg ...................DONE
# Processing img_test/fresh_orange_293.jpeg ...................DONE
# Processing img_test/fresh_orange_294.jpeg ...................DONE
# Processing img_test/fresh_orange_295.jpeg ...................DONE
# Processing img_test/fresh_orange_296.jpeg ...................DONE
# Processing img_test/fresh_orange_297.jpeg ...................DONE
# Processing img_test/fresh_orange_298.jpeg ...................DONE
# Processing img_test/fresh_orange_299.jpeg ...................DONE
# Processing img_test/fresh_orange_3.jpeg ...................DONE
# Processing img_test/fresh_orange_30.jpeg ...................DONE
# Processing img_test/fresh_orange_300.jpeg ...................DONE
# Processing img_test/fresh_orange_302.jpeg ...................DONE
# Processing img_test/fresh_orange_303.jpeg ...................DONE
# Processing img_test/fresh_orange_304.jpeg ...................DONE
# Processing img_test/fresh_orange_305.jpeg ...................DONE
# Processing img_test/fresh_orange_306.jpeg ...................DONE
# Processing img_test/fresh_orange_307.jpeg ...................DONE
# Processing img_test/fresh_orange_308.jpeg ...................DONE
# Processing img_test/fresh_orange_309.jpeg ...................DONE
# Processing img_test/fresh_orange_31.jpeg ...................DONE
# Processing img_test/fresh_orange_310.jpeg ...................DONE
# Processing img_test/fresh_orange_311.jpeg ...................DONE
# Processing img_test/fresh_orange_312.jpeg ...................DONE
# Processing img_test/fresh_orange_313.jpeg ...................DONE
# Processing img_test/fresh_orange_314.jpeg ...................DONE
# Processing img_test/fresh_orange_315.jpeg ...................DONE
# Processing img_test/fresh_orange_317.jpeg ...................DONE
# Processing img_test/fresh_orange_318.jpeg ...................DONE
# Processing img_test/fresh_orange_319.jpeg ...................DONE
# Processing img_test/fresh_orange_32.jpeg ...................DONE
# Processing img_test/fresh_orange_320.jpeg ...................DONE
# Processing img_test/fresh_orange_321.jpeg ...................DONE
# Processing img_test/fresh_orange_322.jpeg ...................DONE
# Processing img_test/fresh_orange_323.jpeg ...................DONE
# Processing img_test/fresh_orange_324.jpeg ...................DONE
# Processing img_test/fresh_orange_325.jpeg ...................DONE
# Processing img_test/fresh_orange_326.jpeg ...................DONE
# Processing img_test/fresh_orange_327.jpeg ...................DONE
# Processing img_test/fresh_orange_328.jpeg ...................DONE
# Processing img_test/fresh_orange_329.jpeg ...................DONE
# Processing img_test/fresh_orange_33.jpeg ...................DONE
# Processing img_test/fresh_orange_331.jpeg ...................DONE
# Processing img_test/fresh_orange_332.jpeg ...................DONE
# Processing img_test/fresh_orange_333.jpeg ...................DONE
# Processing img_test/fresh_orange_334.jpeg ...................DONE
# Processing img_test/fresh_orange_335.jpeg ...................DONE
# Processing img_test/fresh_orange_336.jpeg ...................DONE
# Processing img_test/fresh_orange_337.jpeg ...................DONE
# Processing img_test/fresh_orange_338.jpeg ...................DONE
# Processing img_test/fresh_orange_339.jpeg ...................DONE
# Processing img_test/fresh_orange_34.jpeg ...................DONE
# Processing img_test/fresh_orange_340.jpeg ...................DONE
# Processing img_test/fresh_orange_341.jpeg ...................DONE
# Processing img_test/fresh_orange_342.jpeg ...................DONE
# Processing img_test/fresh_orange_343.jpeg ...................DONE
# Processing img_test/fresh_orange_344.jpeg ...................DONE
# Processing img_test/fresh_orange_346.jpeg ...................DONE
# Processing img_test/fresh_orange_347.jpeg ...................DONE
# Processing img_test/fresh_orange_348.jpeg ...................DONE
# Processing img_test/fresh_orange_349.jpeg ...................DONE
# Processing img_test/fresh_orange_35.jpeg ...................DONE
# Processing img_test/fresh_orange_350.jpeg ...................DONE
# Processing img_test/fresh_orange_351.jpeg ...................DONE
# Processing img_test/fresh_orange_352.jpeg ...................DONE
# Processing img_test/fresh_orange_353.jpeg ...................DONE
# Processing img_test/fresh_orange_354.jpeg ...................DONE
# Processing img_test/fresh_orange_355.jpeg ...................DONE
# Processing img_test/fresh_orange_356.jpeg ...................DONE
# Processing img_test/fresh_orange_357.jpeg ...................DONE
# Processing img_test/fresh_orange_358.jpeg ...................DONE
# Processing img_test/fresh_orange_359.jpeg ...................DONE
# Processing img_test/fresh_orange_360.jfif ...................DONE
# Processing img_test/fresh_orange_361.jpg ...................DONE
# Processing img_test/fresh_orange_362.jpg ...................DONE
# Processing img_test/fresh_orange_363.jpg ...................DONE
# Processing img_test/fresh_orange_364.jpg ...................DONE
# Processing img_test/fresh_orange_365.jpg ...................DONE
# Processing img_test/fresh_orange_366.jpg ...................DONE
# Processing img_test/fresh_orange_367.jfif ...................DONE
# Processing img_test/fresh_orange_368.jpg ...................DONE
# Processing img_test/fresh_orange_369.jpeg ...................DONE
# Processing img_test/fresh_orange_37.jpeg ...................DONE
# Processing img_test/fresh_orange_370.jpg ...................DONE
# Processing img_test/fresh_orange_371.jpg ...................DONE
# Processing img_test/fresh_orange_372.jpg ...................DONE
# Processing img_test/fresh_orange_373.jpg ...................DONE
# Processing img_test/fresh_orange_375.jpg ...................DONE
# Processing img_test/fresh_orange_376.jpg ...................DONE
# Processing img_test/fresh_orange_377.jpg ...................DONE
# Processing img_test/fresh_orange_378.jpg ...................DONE
# Processing img_test/fresh_orange_379.jpg ...................DONE
# Processing img_test/fresh_orange_38.jpeg ...................DONE
# Processing img_test/fresh_orange_380.jpeg ...................DONE
# Processing img_test/fresh_orange_381.jpg ...................DONE
# Processing img_test/fresh_orange_382.jpg ...................DONE
# Processing img_test/fresh_orange_383.jpg ...................DONE
# Processing img_test/fresh_orange_384.jpg ...................DONE
# Processing img_test/fresh_orange_385.jpg ...................DONE
# Processing img_test/fresh_orange_386.jpg ...................DONE
# Processing img_test/fresh_orange_387.jpg ...................DONE
# Processing img_test/fresh_orange_388.jpg ...................DONE
# Processing img_test/fresh_orange_39.jpeg ...................DONE
# Processing img_test/fresh_orange_390.jpg ...................DONE
# Processing img_test/fresh_orange_391.jpeg ...................DONE
# Processing img_test/fresh_orange_392.jpg ...................DONE
# Processing img_test/fresh_orange_393.jpg ...................DONE
# Processing img_test/fresh_orange_394.jpg ...................DONE
# Processing img_test/fresh_orange_395.jpg ...................DONE
# Processing img_test/fresh_orange_396.jpg ...................DONE
# Processing img_test/fresh_orange_397.jpeg ...................DONE
# Processing img_test/fresh_orange_398.jpeg ...................DONE
# Processing img_test/fresh_orange_399.jpeg ...................DONE
# Processing img_test/fresh_orange_4.jpeg ...................DONE
# Processing img_test/fresh_orange_40.jpeg ...................DONE
# Processing img_test/fresh_orange_400.jpeg ...................DONE
# Processing img_test/fresh_orange_401.jpeg ...................DONE
# Processing img_test/fresh_orange_402.jpeg ...................DONE
# Processing img_test/fresh_orange_41.jpeg ...................DONE
# Processing img_test/fresh_orange_42.jpeg ...................DONE
# Processing img_test/fresh_orange_43.jpeg ...................DONE
# Processing img_test/fresh_orange_44.jpeg ...................DONE
# Processing img_test/fresh_orange_45.jpeg ...................DONE
# Processing img_test/fresh_orange_46.jpeg ...................DONE
# Processing img_test/fresh_orange_47.jpeg ...................DONE
# Processing img_test/fresh_orange_48.jpeg ...................DONE
# Processing img_test/fresh_orange_49.jpeg ...................DONE
# Processing img_test/fresh_orange_5.jpeg ...................DONE
# Processing img_test/fresh_orange_50.jpeg ...................DONE
# Processing img_test/fresh_orange_51.jpeg ...................DONE
# Processing img_test/fresh_orange_52.jpeg ...................DONE
# Processing img_test/fresh_orange_53.jpeg ...................DONE
# Processing img_test/fresh_orange_54.jpeg ...................DONE
# Processing img_test/fresh_orange_55.jpeg ...................DONE
# Processing img_test/fresh_orange_57.jpeg ...................DONE
# Processing img_test/fresh_orange_58.jpeg ...................DONE
# Processing img_test/fresh_orange_59.jpeg ...................DONE
# Processing img_test/fresh_orange_6.jpeg ...................DONE
# Processing img_test/fresh_orange_60.jpeg ...................DONE
# Processing img_test/fresh_orange_61.jpeg ...................DONE
# Processing img_test/fresh_orange_62.jpeg ...................DONE
# Processing img_test/fresh_orange_63.jpeg ...................DONE
# Processing img_test/fresh_orange_64.jpeg ...................DONE
# Processing img_test/fresh_orange_65.jpeg ...................DONE
# Processing img_test/fresh_orange_66.jpeg ...................DONE
# Processing img_test/fresh_orange_67.jpeg ...................DONE
# Processing img_test/fresh_orange_68.jpeg ...................DONE
# Processing img_test/fresh_orange_69.jpeg ...................DONE
# Processing img_test/fresh_orange_7.jpeg ...................DONE
# Processing img_test/fresh_orange_70.jpeg ...................DONE
# Processing img_test/fresh_orange_72.jpeg ...................DONE
# Processing img_test/fresh_orange_73.jpeg ...................DONE
# Processing img_test/fresh_orange_74.jpeg ...................DONE
# Processing img_test/fresh_orange_75.jpeg ...................DONE
# Processing img_test/fresh_orange_76.jpeg ...................DONE
# Processing img_test/fresh_orange_77.jpeg ...................DONE
# Processing img_test/fresh_orange_78.jpeg ...................DONE
# Processing img_test/fresh_orange_79.jpeg ...................DONE
# Processing img_test/fresh_orange_8.jpeg ...................DONE
# Processing img_test/fresh_orange_80.jpeg ...................DONE
# Processing img_test/fresh_orange_81.jpeg ...................DONE
# Processing img_test/fresh_orange_82.jpeg ...................DONE
# Processing img_test/fresh_orange_83.jpeg ...................DONE
# Processing img_test/fresh_orange_84.jpeg ...................DONE
# Processing img_test/fresh_orange_85.jpeg ...................DONE
# Processing img_test/fresh_orange_86.jpeg ...................DONE
# Processing img_test/fresh_orange_88.jpeg ...................DONE
# Processing img_test/fresh_orange_89.jpeg ...................DONE
# Processing img_test/fresh_orange_9.jpeg ...................DONE
# Processing img_test/fresh_orange_90.jpeg ...................DONE
# Processing img_test/fresh_orange_91.jpeg ...................DONE
# Processing img_test/fresh_orange_92.jpeg ...................DONE
# Processing img_test/fresh_orange_93.jpeg ...................DONE
# Processing img_test/fresh_orange_94.jpeg ...................DONE
# Processing img_test/fresh_orange_95.jpeg ...................DONE
# Processing img_test/fresh_orange_96.jpeg ...................DONE
# Processing img_test/fresh_orange_97.jpeg ...................DONE
# Processing img_test/fresh_orange_98.jpeg ...................DONE
# Processing img_test/fresh_orange_99.jpeg ...................DONE
# Processing img_test/fresh_orange_a.jpeg ...................DONE
# Processing img_test/fresh_orange_b.jpg ...................DONE
# Processing img_test/fresh_orange_c.png ...................DONE
# Processing img_test/renamed_13.jpeg ...................DONE
# Processing img_test/renamed_15.jpeg ...................DONE
# Processing img_test/renamed_17.jpeg ...................DONE
# Processing img_test/renamed_19.jpeg ...................DONE
# Processing img_test/renamed_2.jpeg ...................DONE
# Processing img_test/renamed_21.jpeg ...................DONE
# Processing img_test/renamed_4.jpeg ...................DONE
# Processing img_test/renamed_7.jpeg ...................DONE
# Processing img_test/renamed_9.jpeg ...................DONE
# Processing img_test/ripe_mango_1.jpg ...................DONE
# Processing img_test/ripe_mango_2.jpg ...................DONE
# Processing img_test/rotten_apple_1.jpg ...................DONE
# Processing img_test/rotten_apple_10.jpg ...................DONE
# Processing img_test/rotten_apple_100.jpeg ...................DONE
# Processing img_test/rotten_apple_101.jpg ...................DONE
# Processing img_test/rotten_apple_102.jpg ...................DONE
# Processing img_test/rotten_apple_104.jpg ...................DONE
# Processing img_test/rotten_apple_105.jpg ...................DONE
# Processing img_test/rotten_apple_106.jpg ...................DONE
# Processing img_test/rotten_apple_107.jpg ...................DONE
# Processing img_test/rotten_apple_108.jpg ...................DONE
# Processing img_test/rotten_apple_109.jpeg ...................DONE
# Processing img_test/rotten_apple_11.jpeg ...................DONE
# Processing img_test/rotten_apple_110.jpeg ...................DONE
# Processing img_test/rotten_apple_111.jpeg ...................DONE
# Processing img_test/rotten_apple_112.jpeg ...................DONE
# Processing img_test/rotten_apple_12.jpeg ...................DONE
# Processing img_test/rotten_apple_13.jpg ...................DONE
# Processing img_test/rotten_apple_14.jpg ...................DONE
# Processing img_test/rotten_apple_15.jpg ...................DONE
# Processing img_test/rotten_apple_16.jpg ...................DONE
# Processing img_test/rotten_apple_17.jpg ...................DONE
# Processing img_test/rotten_apple_2.jpg ...................DONE
# Processing img_test/rotten_apple_20.jpg ...................DONE
# Processing img_test/rotten_apple_21.jpeg ...................DONE
# Processing img_test/rotten_apple_22.jpeg ...................DONE
# Processing img_test/rotten_apple_23.jpeg ...................DONE
# Processing img_test/rotten_apple_24.jpeg ...................DONE
# Processing img_test/rotten_apple_25.jpeg ...................DONE
# Processing img_test/rotten_apple_26.jpeg ...................DONE
# Processing img_test/rotten_apple_27.jpeg ...................DONE
# Processing img_test/rotten_apple_28.jpeg ...................DONE
# Processing img_test/rotten_apple_29.jpeg ...................DONE
# Processing img_test/rotten_apple_3.jpeg ...................DONE
# Processing img_test/rotten_apple_30.jpeg ...................DONE
# Processing img_test/rotten_apple_31.jpeg ...................DONE
# Processing img_test/rotten_apple_32.jpeg ...................DONE
# Processing img_test/rotten_apple_34.jpeg ...................DONE
# Processing img_test/rotten_apple_35.jpeg ...................DONE
# Processing img_test/rotten_apple_36.jpeg ...................DONE
# Processing img_test/rotten_apple_37.jpeg ...................DONE
# Processing img_test/rotten_apple_38.jpeg ...................DONE
# Processing img_test/rotten_apple_39.jpeg ...................DONE
# Processing img_test/rotten_apple_4.jpeg ...................DONE
# Processing img_test/rotten_apple_40.jpeg ...................DONE
# Processing img_test/rotten_apple_41.jpeg ...................DONE
# Processing img_test/rotten_apple_42.jpeg ...................DONE
# Processing img_test/rotten_apple_43.jpeg ...................DONE
# Processing img_test/rotten_apple_44.jpeg ...................DONE
# Processing img_test/rotten_apple_45.jpeg ...................DONE
# Processing img_test/rotten_apple_46.jpeg ...................DONE
# Processing img_test/rotten_apple_47.jpeg ...................DONE
# Processing img_test/rotten_apple_49.jpeg ...................DONE
# Processing img_test/rotten_apple_5.jpeg ...................DONE
# Processing img_test/rotten_apple_50.jpeg ...................DONE
# Processing img_test/rotten_apple_51.jpeg ...................DONE
# Processing img_test/rotten_apple_52.jpeg ...................DONE
# Processing img_test/rotten_apple_53.jpeg ...................DONE
# Processing img_test/rotten_apple_54.jpeg ...................DONE
# Processing img_test/rotten_apple_55.jpeg ...................DONE
# Processing img_test/rotten_apple_56.jpeg ...................DONE
# Processing img_test/rotten_apple_57.jpg ...................DONE
# Processing img_test/rotten_apple_58.jpeg ...................DONE
# Processing img_test/rotten_apple_59.jpeg ...................DONE
# Processing img_test/rotten_apple_6.jpeg ...................DONE
# Processing img_test/rotten_apple_60.jpeg ...................DONE
# Processing img_test/rotten_apple_61.jpeg ...................DONE
# Processing img_test/rotten_apple_63.jpeg ...................DONE
# Processing img_test/rotten_apple_64.jpeg ...................DONE
# Processing img_test/rotten_apple_65.jpeg ...................DONE
# Processing img_test/rotten_apple_66.jpeg ...................DONE
# Processing img_test/rotten_apple_67.jpeg ...................DONE
# Processing img_test/rotten_apple_68.jpeg ...................DONE
# Processing img_test/rotten_apple_69.jpeg ...................DONE
# Processing img_test/rotten_apple_7.jpeg ...................DONE
# Processing img_test/rotten_apple_70.jpeg ...................DONE
# Processing img_test/rotten_apple_71.jpeg ...................DONE
# Processing img_test/rotten_apple_72.jpeg ...................DONE
# Processing img_test/rotten_apple_73.jpeg ...................DONE
# Processing img_test/rotten_apple_74.jpeg ...................DONE
# Processing img_test/rotten_apple_75.jpeg ...................DONE
# Processing img_test/rotten_apple_76.jpeg ...................DONE
# Processing img_test/fresh_orange_330.jpeg ...................DONE
# Processing img_test/fresh_orange_345.jpeg ...................DONE
# Processing img_test/fresh_orange_36.jpeg ...................DONE
# Processing img_test/fresh_orange_374.jpg ...................DONE
# Processing img_test/fresh_orange_389.jpg ...................DONE
# Processing img_test/fresh_orange_403.jpeg ...................DONE
# Processing img_test/fresh_orange_56.jpeg ...................DONE
# Processing img_test/fresh_orange_71.jpeg ...................DONE
# Processing img_test/fresh_orange_87.jpeg ...................DONE
# Processing img_test/renamed_11.jpeg ...................DONE
# Processing img_test/rotten_apple_103.jpg ...................DONE
# Processing img_test/rotten_apple_19.jpg ...................DONE
# Processing img_test/rotten_apple_33.jpeg ...................DONE
# Processing img_test/rotten_apple_48.jpeg ...................DONE
# Processing img_test/rotten_apple_62.jpeg ...................DONE
# Processing img_test/rotten_apple_77.jpeg ...................DONE
# Processing img_test/rotten_apple_78.jpeg ...................DONE
# Processing img_test/rotten_apple_79.jpeg ...................DONE
# Processing img_test/rotten_apple_8.jpeg ...................DONE
# Processing img_test/rotten_apple_80.jpeg ...................DONE
# Processing img_test/rotten_apple_81.jpeg ...................DONE
# Processing img_test/rotten_apple_82.jpeg ...................DONE
# Processing img_test/rotten_apple_83.jpeg ...................DONE
# Processing img_test/rotten_apple_84.jpeg ...................DONE
# Processing img_test/rotten_apple_85.jpeg ...................DONE
# Processing img_test/rotten_apple_86.jpeg ...................DONE
# Processing img_test/rotten_apple_87.jpeg ...................DONE
# Processing img_test/rotten_apple_88.jpeg ...................DONE
# Processing img_test/rotten_apple_89.jpeg ...................DONE
# Processing img_test/rotten_apple_9.jpg ...................DONE
# Processing img_test/rotten_apple_90.jpeg ...................DONE
# Processing img_test/rotten_apple_91.jpeg ...................DONE
# Processing img_test/rotten_apple_92.jpeg ...................DONE
# Processing img_test/rotten_apple_93.jpeg ...................DONE
# Processing img_test/rotten_apple_94.jpeg ...................DONE
# Processing img_test/rotten_apple_95.jpeg ...................DONE
# Processing img_test/rotten_apple_96.jpeg ...................DONE
# Processing img_test/rotten_apple_97.jpeg ...................DONE
# Processing img_test/rotten_apple_98.jpeg ...................DONE
# Processing img_test/rotten_apple_99.jpeg ...................DONE
# Processing img_test/rotten_apple_a.JPG ...................DONE
# Processing img_test/rotten_apple_b.JPG ...................DONE
# Processing img_test/rotten_banana_a.jpeg ...................DONE
# Processing img_test/rotten_banana_b.JPG ...................DONE
# Processing img_test/rotten_mango_a.jpg ...................DONE
# Processing img_test/rotten_orange_a.jpeg ...................DONE

# %%
result_dict = d

# %%
len(result_dict)
# Out:
# 536

# %%
# pickle again

result_pickle_file = os.path.join(pickle_dir, "inception_predition.pickle")
pickle_out = open(result_pickle_file, "wb")
pickle.dump(result_dict, pickle_out)

pickle_out.close()

# %%
# check again
pickle_load = pickle.load(open(result_pickle_file, "rb"))
print(pickle_load)
# Out:
# {'img_test/fresh_orange_372.jpg': 4, 'img_test/fresh_orange_134.jpeg': 3, 'img_test/fresh_orange_273.jpeg': 5, 'img_test/fresh_orange_185.jpeg': 3, 'img_test/rotten_apple_59.jpeg': 4, 'img_test/fresh_orange_233.jpeg': 5, 'img_test/fresh_orange_84.jpeg': 5, 'img_test/fresh_orange_300.jpeg': 3, 'img_test/fresh_orange_113.jpeg': 5, 'img_test/fresh_orange_55.jpeg': 5, 'img_test/fresh_orange_193.jpeg': 5, 'img_test/fresh_orange_294.jpeg': 1, 'img_test/rotten_apple_62.jpeg': 4, 'img_test/fresh_orange_180.jpeg': 3, 'img_test/fresh_orange_297.jpeg': 3, 'img_test/rotten_apple_8.jpeg': 7, 'img_test/fresh_orange_292.jpeg': 5, 'img_test/rotten_apple_104.jpg': 3, 'img_test/fresh_orange_153.jpeg': 5, 'img_test/fresh_orange_222.jpeg': 3, 'img_test/fresh_orange_214.jpeg': 1, 'img_test/fresh_orange_89.jpeg': 5, 'img_test/fresh_orange_28.jpeg': 5, 'img_test/fresh_orange_359.jpeg': 4, 'img_test/fresh_orange_354.jpeg': 4, 'img_test/fresh_orange_119.jpeg': 1, 'img_test/fresh_orange_340.jpeg': 4, 'img_test/fresh_orange_339.jpeg': 4, 'img_test/fresh_orange_80.jpeg': 5, 'img_test/fresh_orange_206.jpeg': 5, 'img_test/fresh_orange_202.jpeg': 5, 'img_test/fresh_orange_26.jpeg': 5, 'img_test/fresh_orange_93.jpeg': 5, 'img_test/fresh_orange_154.jpeg': 5, 'img_test/fresh_orange_394.jpg': 4, 'img_test/fresh_orange_143.jpeg': 5, 'img_test/fresh_orange_234.jpeg': 1, 'img_test/fresh_orange_64.jpeg': 5, 'img_test/fresh_orange_246.jpeg': 1, 'img_test/fresh_orange_306.jpeg': 5, 'img_test/rotten_apple_67.jpeg': 7, 'img_test/fresh_orange_385.jpg': 4, 'img_test/fresh_orange_376.jpg': 4, 'img_test/fresh_orange_159.jpeg': 5, 'img_test/renamed_9.jpeg': 3, 'img_test/fresh_orange_183.jpeg': 5, 'img_test/rotten_apple_33.jpeg': 6, 'img_test/renamed_13.jpeg': 5, 'img_test/fresh_orange_309.jpeg': 1, 'img_test/fresh_orange_a.jpeg': 4, 'img_test/rotten_apple_14.jpg': 7, 'img_test/fresh_orange_145.jpeg': 5, 'img_test/fresh_orange_208.jpeg': 1, 'img_test/fresh_orange_20.jpeg': 1, 'img_test/fresh_orange_179.jpeg': 5, 'img_test/fresh_orange_374.jpg': 4, 'img_test/fresh_orange_128.jpeg': 5, 'img_test/fresh_orange_47.jpeg': 5, 'img_test/fresh_orange_168.jpeg': 5, 'img_test/rotten_apple_5.jpeg': 7, 'img_test/fresh_orange_32.jpeg': 5, 'img_test/fresh_orange_213.jpeg': 5, 'img_test/fresh_orange_1.jpeg': 5, 'img_test/rotten_apple_71.jpeg': 7, 'img_test/fresh_orange_279.jpeg': 5, 'img_test/rotten_apple_110.jpeg': 7, 'img_test/fresh_orange_6.jpeg': 5, 'img_test/rotten_apple_53.jpeg': 7, 'img_test/fresh_orange_182.jpeg': 5, 'img_test/fresh_orange_352.jpeg': 4, 'img_test/rotten_apple_60.jpeg': 7, 'img_test/fresh_orange_348.jpeg': 4, 'img_test/fresh_orange_321.jpeg': 5, 'img_test/fresh_mango_e.jpg': 6, 'img_test/fresh_orange_264.jpeg': 5, 'img_test/rotten_apple_85.jpeg': 7, 'img_test/fresh_orange_194.jpeg': 5, 'img_test/rotten_apple_37.jpeg': 7, 'img_test/fresh_orange_188.jpeg': 5, 'img_test/fresh_orange_285.jpeg': 5, 'img_test/rotten_apple_84.jpeg': 4, 'img_test/fresh_orange_284.jpeg': 3, 'img_test/fresh_orange_349.jpeg': 4, 'img_test/fresh_orange_298.jpeg': 1, 'img_test/fresh_orange_378.jpg': 4, 'img_test/rotten_apple_81.jpeg': 7, 'img_test/fresh_orange_10.jpeg': 5, 'img_test/rotten_apple_93.jpeg': 6, 'img_test/rotten_apple_112.jpeg': 6, 'img_test/fresh_orange_280.jpeg': 3, 'img_test/rotten_apple_70.jpeg': 7, 'img_test/fresh_orange_176.jpeg': 5, 'img_test/fresh_orange_364.jpg': 4, 'img_test/fresh_orange_291.jpeg': 5, 'img_test/fresh_orange_190.jpeg': 5, 'img_test/fresh_orange_88.jpeg': 5, 'img_test/fresh_orange_16.jpeg': 5, 'img_test/fresh_orange_381.jpg': 4, 'img_test/fresh_orange_259.jpeg': 5, 'img_test/fresh_orange_386.jpg': 4, 'img_test/fresh_orange_111.jpeg': 1, 'img_test/fresh_orange_282.jpeg': 5, 'img_test/fresh_orange_82.jpeg': 3, 'img_test/rotten_apple_76.jpeg': 7, 'img_test/fresh_orange_162.jpeg': 5, 'img_test/fresh_orange_235.jpeg': 5, 'img_test/rotten_apple_100.jpeg': 7, 'img_test/rotten_apple_57.jpg': 7, 'img_test/fresh_orange_362.jpg': 4, 'img_test/fresh_orange_333.jpeg': 6,  ...
